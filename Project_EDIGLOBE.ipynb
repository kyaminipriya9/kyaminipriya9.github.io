# %% [markdown]
# <a href="https://colab.research.google.com/github/kyaminipriya9423/kyaminipriya9423.github.io/blob/main/Project_EDIGLOBE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Name : K.Yamini Priya
# #Some changes are made to the original document based on my understanding and few comments are added.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):   # Iterate over files and directories in '/kaggle/input' and print their paths.
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings
warnings.filterwarnings('ignore') # Suppress warnings to ignore them during execution.

# %%
data = pd.read_csv("/content/IMDB-Movie-Data.csv") # Read data from the csv file under this path.

# %%
data.head(15) # Display the data of first 15 rows from the csv file
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# ...

# %%
data.tail(15) # Display the data of last 15 rows from the csv file
# Out:
#      Rank                           Title                     Genre  \
# 985   986                   Your Highness  Adventure,Comedy,Fantasy
# 986   987             Final Destination 5           Horror,Thriller
# 987   988                    Endless Love             Drama,Romance
# 988   989                         Martyrs                    Horror
# 989   990                           Selma   Biography,Drama,History
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# ...

# %% [markdown]
# ### ***THIS PART IS ADDED TO THE ORIGINAL DOCUMENT(Data is displayed in the given range)***

# %%
data.iloc[100:201]  # iloc is used for index-based slicing and Display the data of 100-200 rows from the csv file
# Out:
#      Rank                    Title                      Genre  \
# 100   101                   Legend      Biography,Crime,Drama
# 101   102                     Thor   Action,Adventure,Fantasy
# 102   103              The Martian     Adventure,Drama,Sci-Fi
# 103   104             Contratiempo     Crime,Mystery,Thriller
# 104   105  The Man from U.N.C.L.E.    Action,Adventure,Comedy
# ..    ...                      ...                        ...
# 196   197                   Hacker       Crime,Drama,Thriller
# 197   198            Into the Wild  Adventure,Biography,Drama
# 198   199       The Imitation Game   Biography,Drama,Thriller
# 199   200     Central Intelligence        Action,Comedy,Crime
# 200   201         Edge of Tomorrow    Action,Adventure,Sci-Fi
#
#                                            Description  \
# 100  Identical twin gangsters Ronald and Reginald K...
# 101  The powerful but arrogant god Thor is cast out...
# ...

# %%
data.shape # Display the no of rows and columns
# Out:
# (1000, 12)

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 1000
# Number of Columns 12

# %%
data.info() # Display summary information of the DataFrame 'data'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.isnull().sum() # Counts the no of missing values
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# In the above output we have 128 missing values of Revenue and 64 missing values of Metascore data from the dataset.

# %%
import matplotlib.pyplot as plt # Visualising missing values with the help of a map
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %%
data = data.dropna(axis=0)

# %%
sns.heatmap(data.isnull())
plt.show()

# %%
dup_data=data.duplicated().any() # Check if there are any duplicate values and print the result
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %%
data.describe() # Display summary statistics of the data
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
data[data['Runtime (Minutes)']>=150]['Title'] # Retrieve titles of movies with a runtime of 150 minutes or more
# Out:
# 36                                          Interstellar
# 54                                       The Dark Knight
# 55                                               Silence
# 60                    Batman v Superman: Dawn of Justice
# 75              Pirates of the Caribbean: At World's End
# 77                                  Inglourious Basterds
# 78            Pirates of the Caribbean: Dead Man's Chest
# 82                               The Wolf of Wall Street
# 87                                                Avatar
# 88                                     The Hateful Eight
# 90                                             Prisoners
# 99                                          The Departed
# 124                                The Dark Knight Rises
# 126                      Transformers: Age of Extinction
# 129                                         The Revenant
# 144                                     Django Unchained
# ...

# %%
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year") # Bar graph between Votes and Year
plt.show()

# %%
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year") # Bar graph between Revenue and Year
plt.show()

# %%
data.groupby('Director')['Rating'].mean().sort_values(ascending=True) # Calculate mean ratings and sort them in ascending order
# Out:
# Director
# Jason Friedberg                     1.90
# James Wong                          2.70
# George Nolfi                        3.90
# Joey Curtis                         4.00
# Sam Taylor-Johnson                  4.10
#                                     ...
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
# Makoto Shinkai                      8.60
# Olivier Nakache                     8.60
# Christopher Nolan                   8.68
# Name: Rating, Length: 524, dtype: float64

# %%
le =data.nlargest(20,'Runtime (Minutes)')[['Title','Runtime (Minutes)']]. \
set_index('Title')  #  Extrat top 20 movies

# %%
sns.barplot(data=le, x='Runtime (Minutes)', y='Title')
plt.title('Top 20 Lengthy Movies')
plt.xlabel('Runtime (Minutes)') # Bar graph between top 20 movies and their runtime
plt.ylabel('Title')
plt.show()

# %%
data.columns # Display the headings of the columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]['Title'] # Retrieve the title of the movie with the maximum revenue
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %% [markdown]
# # Added a code which generates the title of the movie which has maximum rating and minimum votes

# %%
data[data['Rating'].max() == data['Rating']]['Title'] # Retrieve the title of the movie with the maximum rating
# Out:
# 54    The Dark Knight
# Name: Title, dtype: object

# %%
data[data['Votes'].min() == data['Votes']]['Title'] # Retrieve the title of the movie with the minimum votes
# Out:
# 250    Bonjour Anne
# Name: Title, dtype: object

# %%
top_25=data.nlargest(25,'Rating')[['Title','Rating','Director']].set_index('Title')

# %%
top_25
# Out:
#                          Rating                          Director
# Title
# The Dark Knight             9.0                 Christopher Nolan
# Inception                   8.8                 Christopher Nolan
# Interstellar                8.6                 Christopher Nolan
# Kimi no na wa               8.6                    Makoto Shinkai
# The Intouchables            8.6                   Olivier Nakache
# The Prestige                8.5                 Christopher Nolan
# The Departed                8.5                   Martin Scorsese
# The Dark Knight Rises       8.5                 Christopher Nolan
# Whiplash                    8.5                   Damien Chazelle
# The Lives of Others         8.5  Florian Henckel von Donnersmarck
# Taare Zameen Par            8.5                        Aamir Khan
# Django Unchained            8.4                 Quentin Tarantino
# 3 Idiots                    8.4                   Rajkumar Hirani
# ...

# %%
sns.barplot(x='Rating', y='Title', data=top_25)
plt.title("Display Top 25 Highest Rated Movie Titles")
plt.xlabel("Rating")
plt.ylabel("Movie Title")
plt.show() # Bar graph between top 25 highest rated movie titles and their ratings

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data.sort_values(by='Rating',ascending=True).head(20) # Sort the DataFrame "data" by 'Rating' column in ascending order and display the first 20 rows.
# Out:
#      Rank                                      Title  \
# 829   830                             Disaster Movie
# 871   872                       Dragonball Evolution
# 237   238                   The Disappointments Room
# 525   526                        Birth of the Dragon
# 616   617                       2307: Winter's Dream
# 63     64                       Fifty Shades of Grey
# 552   553                             Fantastic Four
# 952   953                         Sex and the City 2
# 508   509                                   Movie 43
# 936   937       The Human Centipede (First Sequence)
# 555   556                          The Boy Next Door
# 787   788                                  Max Steel
# 155   156               Aliens vs Predator - Requiem
# 431   432                                Zoolander 2
# 522   523                                     Viking
# 970   971                          Texas Chainsaw 3D
# 250   251                               Bonjour Anne
# ...

# %%
top_15 = data.nlargest(15,'Revenue (Millions)')[['Title','Director','Revenue (Millions)']].set_index('Title')

# %%
sns.barplot(x='Revenue (Millions)', y=top_15.index, data=top_15)
plt.title("Display Top 10 Highest Revenue Movie Titles")
plt.xlabel("Revenue (Millions)")
plt.ylabel("Movie Title")
plt.show() # Bar graph between the revenue of the top 10 movies with the highest ratings.

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data1=data.groupby('Year')['Year','Rating'].mean().\
sort_values(by='Rating',ascending=False).set_index('Year') # Group by year, calculate mean rating, sort by rating, and set 'Year' as index.

# %%
data1
# Out:
#           Rating
# Year
# 2006.0  7.143902
# 2007.0  7.140909
# 2011.0  6.945614
# 2012.0  6.933871
# 2009.0  6.911111
# 2010.0  6.894737
# 2013.0  6.832143
# 2014.0  6.822581
# 2008.0  6.708333
# 2015.0  6.674312
# 2016.0  6.644444

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=data1.index, y=data1['Rating'])
plt.title("Bar Plot of Ratings")
plt.xlabel("Index")
plt.ylabel("Rating")
plt.show()

# %%
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data) # Scatter plot between Revenue and Rating
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# Define a function to categorize ratings as 'Excellent', 'Good', or 'Average' based on their values.
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['rating_cat']=data['Rating'].apply(rating)

# %%
data.head(2)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
#
#                                          Description      Director  \
# 0  A group of intergalactic criminals are forced ...    James Gunn
# 1  Following clues to the origin of mankind, a te...  Ridley Scott
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
#
#    Rating   Votes  Revenue (Millions)  Metascore rating_cat
# 0     8.1  757074              333.13       76.0  Excellent
# 1     7.0  485820              126.46       65.0  Excellent

# %%
list1=[] # Splits the values in Genre by comma and stores them in a list
for value in data['Genre']:
    list1.append(value.split(','))

# %% [markdown]
# # Added a line of code which print the above list of genres which are comma separated.

# %%
print(list1)
# Out:
# [['Action', 'Adventure', 'Sci-Fi'], ['Adventure', 'Mystery', 'Sci-Fi'], ['Horror', 'Thriller'], ['Animation', 'Comedy', 'Family'], ['Action', 'Adventure', 'Fantasy'], ['Action', 'Adventure', 'Fantasy'], ['Comedy', 'Drama', 'Music'], ['Action', 'Adventure', 'Biography'], ['Adventure', 'Drama', 'Romance'], ['Adventure', 'Family', 'Fantasy'], ['Biography', 'Drama', 'History'], ['Action', 'Adventure', 'Sci-Fi'], ['Animation', 'Adventure', 'Comedy'], ['Action', 'Comedy', 'Drama'], ['Animation', 'Adventure', 'Comedy'], ['Biography', 'Drama', 'History'], ['Action', 'Thriller'], ['Biography', 'Drama'], ['Drama', 'Mystery', 'Sci-Fi'], ['Adventure', 'Drama', 'Thriller'], ['Drama'], ['Animation', 'Adventure', 'Comedy'], ['Action', 'Adventure', 'Sci-Fi'], ['Comedy'], ['Action', 'Adventure', 'Drama'], ['Comedy'], ['Drama', 'Thriller'], ['Action', 'Adventure', 'Sci-Fi'], ['Action', 'Adventure', 'Comedy'], ['Action', 'Horror', 'Sci-Fi'], ['Action', 'Adventure', 'Sci-Fi'], ['Adventure', 'Drama', 'Sc
# ...

# %%
data['temp']=list1 # Assigns the lists stored in list1 to temp.

# %% [markdown]
# The next two codes prints the values stored in the 'temp' column of the dataset and first few rows of the 'temp' column in the dataset respectively

# %%
print(data['temp'])
# Out:
# 0       [Action, Adventure, Sci-Fi]
# 1      [Adventure, Mystery, Sci-Fi]
# 2                [Horror, Thriller]
# 3       [Animation, Comedy, Family]
# 4      [Action, Adventure, Fantasy]
#                    ...
# 993     [Action, Adventure, Horror]
# 994                        [Comedy]
# 996                        [Horror]
# 997         [Drama, Music, Romance]
# 999       [Comedy, Family, Fantasy]
# Name: temp, Length: 838, dtype: object

# %%
print(data['temp'].head())
# Out:
# 0     [Action, Adventure, Sci-Fi]
# 1    [Adventure, Mystery, Sci-Fi]
# 2              [Horror, Thriller]
# 3     [Animation, Comedy, Family]
# 4    [Action, Adventure, Fantasy]
# Name: temp, dtype: object

# %%
genre=input("Enter Genre you want to count : ").title() # Prompt user for a genre input, count occurrences of the genre in the 'temp' column.
count=0
for value in data['temp']:
    if genre in value:
        count=count+1
print("Total Count is",count)
# Out:
# Enter Genre you want to count : Action
# Total Count is 277

# %%
len(data[data['Genre'].str.contains('action',case=False)]) # Count occurrences of the substring 'action' in the 'Genre' column.
# Out:
# 277
